# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a set of bibtex of publications and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)).
#
# The core python code is also in `pubsFromBibs.py`.
# Run either from the `markdown_generator` folder after replacing updating the publist dictionary with:
# * bib file names
# * specific venue keys based on your bib file preferences
# * any specific pre-text for specific files
# * Collection Name (future feature)
#
# TODO: Make this work with other databases of citations,
# TODO: Merge this with the existing TSV parsing solution

# %%
from pybtex.database.input import bibtex
import pybtex.database.input.bibtex 
from sphinx_astrorefs import pybtex_astro
from time import strptime
import string
import html
import os
import re

# %%
pybtex_astro.register()

# %%
#todo: incorporate different collection types rather than a catch all publications, requires other changes to template
publist = {

    "journal":{
        "file": "export-bibtex.bib",
        "venuekey" : "journal",
        "venue-pretext" : "",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
    } 
}

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
for pubsource in publist:
    parser = bibtex.Parser()
    bibdata = parser.parse_file(publist[pubsource]["file"])

    #loop through the individual references in a given bibtex file
    for bib_id in bibdata.entries:
        #reset default date
        pub_year = "1900"
        pub_month = "01"
        pub_day = "01"
        
        b = bibdata.entries[bib_id].fields
        
        try:
            pub_year = f'{b["year"]}'

            #todo: this hack for month and day needs some cleanup
            if "month" in b.keys(): 
                if(len(b["month"])<3):
                    pub_month = "0"+b["month"]
                    pub_month = pub_month[-2:]
                elif(b["month"] not in range(12)):
                    tmnth = strptime(b["month"][:3],'%b').tm_mon   
                    pub_month = "{:02d}".format(tmnth) 
                else:
                    pub_month = str(b["month"])
            if "day" in b.keys(): 
                pub_day = str(b["day"])

                
            pub_date = pub_year+"-"+pub_month+"-"+pub_day
            
            #strip out {} as needed (some bibtex entries that maintain formatting)
            clean_title = b["title"].replace("{", "").replace("}","").replace("\\","").replace(" ","-")    

            url_slug = re.sub("\\[.*\\]|[^a-zA-Z0-9_-]", "", clean_title)
            url_slug = url_slug.replace("--","-")

            md_filename = (str(pub_date) + "-" + url_slug + ".md").replace("--","-")
            html_filename = (str(pub_date) + "-" + url_slug).replace("--","-")

            #Build Citation from text
            citation = ""

            #citation authors - todo - add highlighting for primary author?
            for author in bibdata.entries[bib_id].persons["author"]:
                if author.first_names and author.last_names:
                    citation = citation+" "+author.first_names[0]+" "+author.last_names[0]+", "

            #citation title
            citation = citation + "\"" + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + ".\""

            #add venue logic depending on citation type
            venue = publist[pubsource]["venue-pretext"]+b[publist[pubsource]["venuekey"]].replace("{", "").replace("}","").replace("\\","")

            citation = citation + " " + html_escape(venue)
            citation = citation + ", " + pub_year + "."

            
            ## YAML variables
            md = "---\ntitle: \""   + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + '"\n'
            
            md += """collection: """ +  publist[pubsource]["collection"]["name"]

            md += """\npermalink: """ + publist[pubsource]["collection"]["permalink"]  + html_filename
            
            note = False
            if "note" in b.keys():
                if len(str(b["note"])) > 5:
                    md += "\nexcerpt: '" + html_escape(b["note"]) + "'"
                    note = True

            md += "\ndate: " + str(pub_date) 

            md += "\nvenue: '" + html_escape(venue) + "'"
            
            url = False
            if "url" in b.keys():
                if len(str(b["url"])) > 5:
                    md += "\npaperurl: '" + b["url"] + "'"
                    url = True

            md += "\ncitation: '" + html_escape(citation) + "'"

            md += "\n---"

            
            ## Markdown description for individual page
            if note:
                md += "\n" + html_escape(b["note"]) + "\n"

            if url:
                md += "\n[Access paper here](" + b["url"] + "){:target=\"_blank\"}\n" 
            else:
                md += "\nUse [Google Scholar](https://scholar.google.com/scholar?q="+html.escape(clean_title.replace("-","+"))+"){:target=\"_blank\"} for full citation"

            md_filename = os.path.basename(md_filename)

            with open("/home/mrabus/github/MarkusRabus.github.io/_publications/" + md_filename, 'w') as f:
                f.write(md)
            print(f'SUCESSFULLY PARSED {bib_id}: \"', b["title"][:60],"..."*(len(b['title'])>60),"\"")
        # field may not exist for a reference
        except KeyError as e:
            print(f'WARNING Missing Expected Field {e} from entry {bib_id}: \"', b["title"][:30],"..."*(len(b['title'])>30),"\"")
            continue
# Out:
# SUCESSFULLY PARSED 2020AJ....160..235B: " {TOI-481 b and TOI-892 b: Two Long-period Hot Jupiters from  ... "
# SUCESSFULLY PARSED 2020AJ....160..222J: " {HATS-37Ab and HATS-38b: Two Transiting Hot Neptunes in the  ... "
# SUCESSFULLY PARSED 2020AJ....160..179M: " {TESS Hunt for Young and Maturing Exoplanets (THYME). III. A ... "
# SUCESSFULLY PARSED 2020A&A...642A.193M: " {TDCOSMO. II. Six new time delays in lensed quasars from hig ... "
# SUCESSFULLY PARSED 2020AJ....160...74H: " {OGLE-2017-BLG-0406: Spitzer Microlens Parallax Reveals Satu ... "
# SUCESSFULLY PARSED 2020MNRAS.495.3881H: " {Large-scale changes of the cloud coverage in the {\ensurema ... "
# SUCESSFULLY PARSED 2020AJ....159..267B: " {HATS-71b: A Giant Planet Transiting an M3 Dwarf Star in TES ... "
# SUCESSFULLY PARSED 2020Natur.581..147B: " {Very regular high-frequency pulsation modes in young interm ... "
# SUCESSFULLY PARSED 2020AJ....159..173H: " {HATS-47b, HATS-48Ab, HATS-49b, and HATS-72b: Four Warm Gian ... "
# SUCESSFULLY PARSED 2020AJ....159..145J: " {TOI-677b: A Warm Jupiter (P = 11.2 days) on an Eccentric Or ... "
# SUCESSFULLY PARSED 2020ApJ...891....3Z: " {Spitzer Microlensing Parallax Reveals Two Isolated Stars in ... "
# SUCESSFULLY PARSED 2020AJ....159...76M: " {OGLE-2013-BLG-0911Lb: A Secondary on the Brown-dwarf Planet ... "
# SUCESSFULLY PARSED 2020A&A...633A..30M: " {The highly inflated giant planet WASP-174b}  "
# SUCESSFULLY PARSED 2019MNRAS.490.4230S: " {Transit timing variations in the WASP-4 planetary system}  "
# SUCESSFULLY PARSED 2019AJ....158..212N: " {OGLE-2015-BLG-1649Lb: A Gas Giant Planet around a Low-mass  ... "
# SUCESSFULLY PARSED 2019MNRAS.488.3308L: " {OGLE-2017-BLG-1186: first application of asteroseismology a ... "
# SUCESSFULLY PARSED 2019MNRAS.488..536H: " {Two temperate sub-Neptunes transiting the star EPIC 2127374 ... "
# SUCESSFULLY PARSED 2019A&A...629A..97B: " {COSMOGRAIL. XVIII. time delays of the quadruply lensed quas ... "
# SUCESSFULLY PARSED 2019MNRAS.487.4603T: " {An analysis of binary microlensing event OGLE-2015-BLG-0060 ... "
# SUCESSFULLY PARSED 2019ApJ...881L..19V: " {TESS Spots a Compact System of Super-Earths around the Nake ... "
# SUCESSFULLY PARSED 2019AJ....158...63E: " {HATS-54b-HATS-58Ab: Five New Transiting Hot Jupiters Includ ... "
# SUCESSFULLY PARSED 2019AJ....158...45B: " {HD 1397b: A Transiting Warm Giant Planet Orbiting A V = 7.8 ... "
# SUCESSFULLY PARSED 2019MNRAS.485.5168M: " {Physical properties and transmission spectrum of the WASP-7 ... "
# SUCESSFULLY PARSED 2019AJ....157..215S: " {OGLE-2018-BLG-0022: A Nearby M-dwarf Binary}  "
# SUCESSFULLY PARSED 2019MNRAS.484.5608D: " {OGLE-2014-BLG-1186: gravitational microlensing providing ev ... "
# SUCESSFULLY PARSED 2019MNRAS.484.2674R: " {A discontinuity in the T$_{eff}$-radius relation of M-dwarf ... "
# SUCESSFULLY PARSED 2019MNRAS.484.2656L: " {Towards reliable uncertainties in IR interferometry: the bo ... "
# SUCESSFULLY PARSED 2019AJ....157..106S: " {Spitzer Microlensing Parallax for OGLE-2017-BLG-0896 Reveal ... "
# SUCESSFULLY PARSED 2019AJ....157..100J: " {K2-287 b: An Eccentric Warm Saturn Transiting a G-dwarf}  "
# SUCESSFULLY PARSED 2019MNRAS.483.1970B: " {K2-161b: a low-density super-Neptune on an eccentric orbit}  "
# SUCESSFULLY PARSED 2019AJ....157...55H: " {HATS-60b-HATS-69b: 10 Transiting Planets from HATSouth}  "
# SUCESSFULLY PARSED 2019AJ....157...31Z: " {HATS-70b: A 13 MJ Brown Dwarf Transiting an A Star}  "
# SUCESSFULLY PARSED 2018AJ....156..216S: " {HATS-59b,c: A Transiting Hot Jupiter and a Cold Massive Gia ... "
# SUCESSFULLY PARSED 2018A&A...616A.183B: " {COSMOGRAIL. XVII. Time delays for the quadruply imaged quas ... "
# SUCESSFULLY PARSED 2018MNRAS.478.5356S: " {K2-237 b and K2-238 b: discovery and characterization of tw ... "
# SUCESSFULLY PARSED 2018MNRAS.477.3406B: " {HATS-39b, HATS-40b, HATS-41b, and HATS-42b: three inflated  ... "
# SUCESSFULLY PARSED 2018MNRAS.477.2572B: " {K2-232 b: a transiting warm Saturn on an eccentric P = 11.2 ... "
# SUCESSFULLY PARSED 2018ApJ...859...82H: " {OGLE-2017-BLG-0329L: A Microlensing Binary Characterized wi ... "
# SUCESSFULLY PARSED 2018A&A...613A..76J: " {A hot Saturn on an eccentric orbit around the giant star K2 ... "
# SUCESSFULLY PARSED 2018MNRAS.475.1809G: " {K2-140b - an eccentric 6.57 d transiting hot Jupiter in Vir ... "
# SUCESSFULLY PARSED 2018AcA....68....1U: " {OGLE-2017-BLG-1434Lb: Eighth q<1{\texttimes}10$^{-4}$ Mass- ... "
# SUCESSFULLY PARSED 2018AJ....155..119B: " {HATS-36b and 24 Other Transiting/Eclipsing Systems from the ... "
# SUCESSFULLY PARSED 2018AJ....155..112B: " {HATS-43b, HATS-44b, HATS-45b, and HATS-46b: Four Short-peri ... "
# SUCESSFULLY PARSED 2018AJ....155...79H: " {HATS-50b through HATS-53b: Four Transiting Hot Jupiters Orb ... "
# SUCESSFULLY PARSED 2018A&A...610A..20E: " {High-resolution Imaging of Transiting Extrasolar Planetary  ... "
# SUCESSFULLY PARSED 2018AJ....155...40R: " {OGLE-2016-BLG-1190Lb: The First Spitzer Bulge Planet Lies N ... "
# SUCESSFULLY PARSED 2018A&A...609A..71C: " {COSMOGRAIL: the COSmological MOnitoring of GRAvItational Le ... "
# SUCESSFULLY PARSED 2017MNRAS.471.4374E: " {K2-113: a dense hot-Jupiter transiting a solar analogue}  "
# SUCESSFULLY PARSED 2017A&A...607A.127S: " {The 2014-2017 outburst of the young star ASASSN-13db. A tim ... "
# SUCESSFULLY PARSED 2017ApJ...848L..27T: " {The Emergence of a Lanthanide-rich Kilonova Following the M ... "
# SUCESSFULLY PARSED 2017ApJ...848L..12A: " {Multi-messenger Observations of a Binary Neutron Star Merge ... "
# SUCESSFULLY PARSED 2017MNRAS.468..835B: " {HATS-22b, HATS-23b and HATS-24b: three new transiting super ... "
# SUCESSFULLY PARSED 2017A&A...601A..34L: " {Resolved astrometric orbits of ten O-type binaries}  "
# SUCESSFULLY PARSED 2017MNRAS.466.2710R: " {Faint-source-star planetary microlensing: the discovery of  ... "
# SUCESSFULLY PARSED 2017MNRAS.465..843M: " {Orbital alignment and star-spot properties in the WASP-52 p ... "
# SUCESSFULLY PARSED 2017A&A...597A..49G: " {MiNDSTEp differential photometry of the gravitationally len ... "
# SUCESSFULLY PARSED 2016PASP..128l4402B: " {An Independent Discovery of Two Hot Jupiters from the K2 Mi ... "
# SUCESSFULLY PARSED 2016PASP..128l4401H: " {Campaign 9 of the K2 Mission: Observational Parameters, Sci ... "
# SUCESSFULLY PARSED 2016AJ....152..161D: " {HATS-31b through HATS-35b: Five Transiting Hot Jupiters Dis ... "
# SUCESSFULLY PARSED 2016ApJ...831..183S: " {The First Simultaneous Microlensing Observations by Two Spa ... "
# SUCESSFULLY PARSED 2016AJ....152..127P: " {HATS-18b: An Extreme Short-period Massive Transiting Planet ... "
# SUCESSFULLY PARSED 2016ApJ...830...43E: " {Discovery and Validation of a High-Density sub-Neptune from ... "
# SUCESSFULLY PARSED 2016AJ....152..108E: " {HATS-25b through HATS-30b: A Half-dozen New Inflated Transi ... "
# SUCESSFULLY PARSED 2016AJ....152...88R: " {HATS-11b AND HATS-12b: Two Transiting Hot Jupiters Orbiting ... "
# SUCESSFULLY PARSED 2016ApJ...828...53H: " {OGLE-2015-BLG-0479LA,B: Binary Gravitational Microlens Char ... "
# SUCESSFULLY PARSED 2016A&A...592A.120F: " {Many new variable stars discovered in the core of the globu ... "
# SUCESSFULLY PARSED 2016PASP..128g4401C: " {HATS-15b and HATS-16b: Two Massive Planets Transiting Old G ... "
# SUCESSFULLY PARSED 2016ApJ...825...60Z: " {Mass Measurements of Isolated Objects from Space-based Micr ... "
# SUCESSFULLY PARSED 2016ApJ...823...63P: " {The Spitzer Microlensing Program as a Probe for Globular Cl ... "
# SUCESSFULLY PARSED 2016A&A...589A..58E: " {High-resolution Imaging of Transiting Extrasolar Planetary  ... "
# SUCESSFULLY PARSED 2016MNRAS.457.4205S: " {High-precision photometry by telescope defocussing - VIII.  ... "
# SUCESSFULLY PARSED 2016AJ....151...89B: " {HATS-17b: A Transiting Compact Warm Jupiter in a 16.3 Day C ... "
# SUCESSFULLY PARSED 2016A&A...588A.128F: " {Exploring the crowded central region of ten Galactic globul ... "
# SUCESSFULLY PARSED 2016ApJ...820...79B: " {Spitzer Observations of OGLE-2015-BLG-1212 Reveal a New Pat ... "
# SUCESSFULLY PARSED 2016ApJ...819...93S: " {Spitzer Parallax of OGLE-2015-BLG-0966: A Cold Neptune in t ... "
# SUCESSFULLY PARSED 2016MNRAS.456..990C: " {Physical properties of the planetary systems WASP-45 and WA ... "
# SUCESSFULLY PARSED 2015MNRAS.454.3094S: " {Larger and faster: revised properties and a shorter orbital ... "
# SUCESSFULLY PARSED 2015A&A...584A.104M: " {Rotation periods and astrometric motions of the Luhman 16AB ... "
# SUCESSFULLY PARSED 2015ApJ...813..111B: " {HATS-7b: A Hot Super Neptune Transiting a Quiet K Dwarf Sta ... "
# SUCESSFULLY PARSED 2015ApJ...812..136B: " {Red Noise Versus Planetary Interpretations in the Microlens ... "
# SUCESSFULLY PARSED 2015MNRAS.451.2263Z: " {A 0.24+0.18 M$_{{\ensuremath{\odot}}}$ double-lined eclipsi ... "
# SUCESSFULLY PARSED 2015AJ....150...49B: " {HATS-8b: A Low-density Transiting Super-Neptune}  "
# SUCESSFULLY PARSED 2015A&A...580A..63M: " {HATS-13b and HATS-14b: two transiting hot Jupiters from the ... "
# SUCESSFULLY PARSED 2015AJ....150...33B: " {HATS9-b and HATS10-b: Two Compact Hot Jupiters in Field 7 o ... "
# SUCESSFULLY PARSED 2015A&A...578A.128K: " {A census of variability in globular cluster M 68 (NGC 4590) ... "
# SUCESSFULLY PARSED 2015A&A...578A...9H: " {Strong near-infrared carbon in the Type Ia supernova iPTF13 ... "
# SUCESSFULLY PARSED 2015ApJ...804...20C: " {Pathway to the Galactic Distribution of Planets: Combined S ... "
# SUCESSFULLY PARSED 2015AJ....149..166H: " {HATS-6b: A Warm Saturn Transiting an Early M Dwarf Star, an ... "
# SUCESSFULLY PARSED 2015MNRAS.447..711S: " {High-precision photometry by telescope defocusing - VII. Th ... "
# SUCESSFULLY PARSED 2015A&A...573A.103S: " {Searching for variable stars in the cores of five metal-ric ... "
# SUCESSFULLY PARSED 2014MNRAS.444..776S: " {High-precision photometry by telescope defocussing - VI. WA ... "
# SUCESSFULLY PARSED 2014AJ....148...29J: " {HATS-4b: A Dense Hot Jupiter Transiting a Super Metal-rich  ... "
# SUCESSFULLY PARSED 2014A&A...568A.127M: " {Physical properties of the WASP-67 planetary system from mu ... "
# SUCESSFULLY PARSED 2014A&A...567A..64H: " {Orbital and physical parameters of eclipsing binaries from  ... "
# SUCESSFULLY PARSED 2014AJ....147..144Z: " {HATS-5b: A Transiting Hot Saturn from the HATSouth Survey}  "
# SUCESSFULLY PARSED 2014Natur.508...72B: " {A ring system detected around the Centaur (10199) Chariklo}  "
# SUCESSFULLY PARSED 2014ApJ...782...48T: " {A Super-Jupiter Orbiting a Late-type Star: A Refined Analys ... "
# SUCESSFULLY PARSED 2014A&A...562A.126M: " {Physical properties and transmission spectrum of the WASP-8 ... "
# SUCESSFULLY PARSED 2014MNRAS.437.2831Z: " {The mass-radius relationship for very low mass stars: four  ... "
# SUCESSFULLY PARSED 2013ApJ...778..184J: " {A Ground-based Optical Transmission Spectrum of WASP-6b}  "
# SUCESSFULLY PARSED 2013AJ....146..113B: " {HATS-3b: An Inflated Hot Jupiter Transiting an F-type Star}  "
# SUCESSFULLY PARSED 2013A&A...558A..55M: " {HATS-2b: A transiting extrasolar planet orbiting a K-type s ... "
# SUCESSFULLY PARSED 2013MNRAS.434.1220A: " {A detailed census of variable stars in the globular cluster ... "
# SUCESSFULLY PARSED 2013A&A...555A..36K: " {Estimating the parameters of globular cluster M 30 (NGC 709 ... "
# SUCESSFULLY PARSED 2013A&A...553A.111S: " {EMCCD photometry reveals two new variable stars in the crow ... "
# SUCESSFULLY PARSED 2013PASP..125..154B: " {HATSouth: A Global Network of Fully Automated Identical Wid ... "
# SUCESSFULLY PARSED 2013AJ....145....5P: " {HATS-1b: The First Transiting Planet Discovered by the HATS ... "
# SUCESSFULLY PARSED 2012MNRAS.420.3017A: " {An eclipsing post-common-envelope binary in the field of th ... "
# SUCESSFULLY PARSED 2012A&A...539A..14E: " {Planetary transit candidates in the CoRoT-SRc01 field}  "
# SUCESSFULLY PARSED 2012A&A...538A.112C: " {Planetary transit candidates in the CoRoT LRa01 field}  "
# SUCESSFULLY PARSED 2011ApJ...743..162P: " {A Search for the Transit of HD 168443b: Improved Orbital Pa ... "
# SUCESSFULLY PARSED 2011ApJ...741..114M: " {TrES-5: A Massive Jupiter-sized Planet Transiting a Cool G  ... "
# SUCESSFULLY PARSED 2011AJ....142..115D: " {TERMS Photometry of Known Transiting Exoplanets}  "
# SUCESSFULLY PARSED 2010SoSyR..44..520L: " {Exoplanet discoveries with the CoRoT space observatory}  "
# SUCESSFULLY PARSED 2010AJ....139.1481A: " {Ground-based Near-infrared Observations of the Secondary Ec ... "
# SUCESSFULLY PARSED 2010Natur.464..384D: " {A transiting giant planet with a temperature between 250K a ... "
# SUCESSFULLY PARSED 2009A&A...508.1011R: " {Transit timing analysis of the exoplanets TrES-1 and TrES-2 ... "
# SUCESSFULLY PARSED 2009A&A...506..501C: " {Planetary transit candidates in CoRoT-LRc01 field}  "
# SUCESSFULLY PARSED 2009A&A...506..343D: " {Ground-based photometry of space-based transit detections:  ... "
# SUCESSFULLY PARSED 2009A&A...506..321M: " {Planetary transit candidates in the CoRoT initial run: reso ... "
# SUCESSFULLY PARSED 2009A&A...506..281R: " {Transiting exoplanets from the CoRoT space mission. VII. Th ... "
# SUCESSFULLY PARSED 2009ApJ...691.1145S: " {A New Spectroscopic and Photometric Analysis of the Transit ... "
# SUCESSFULLY PARSED 2009A&A...494..391R: " {A cool starspot or a second transiting planet in the TrES-1 ... "
# SUCESSFULLY PARSED 2008CoAst.157..307F: " {New multisite observations of {\ensuremath{\delta}} Scuti s ... "
# SUCESSFULLY PARSED 2008ApJ...687.1253D: " {T-Lyr1-17236: A Long-Period Low-Mass Eclipsing Binary}  "
# SUCESSFULLY PARSED 2008A&A...488L..47M: " {Transiting exoplanets from the CoRoT space mission. V. CoRo ... "
# SUCESSFULLY PARSED 2008A&A...488..763H: " {Misaligned spin-orbit in the XO-3 planetary system?}  "
# SUCESSFULLY PARSED 2008A&A...487L...5A: " {Limits to the planet candidate GJ 436c}  "
# SUCESSFULLY PARSED 2007ApJ...667L.195M: " {TrES-4: A Transiting Hot Jupiter of Very Low Density}  "
# SUCESSFULLY PARSED 2007ApJ...663L..37O: " {TrES-3: A Nearby, Massive, Transiting Hot Jupiter in a 31 H ... "
# SUCESSFULLY PARSED 2006ApJ...651L..61O: " {TrES-2: The First Transiting Planet in the Kepler Field}  "
# SUCESSFULLY PARSED 2006JEMat..35..877R: " {Rapid thermal processing of silicon wafers with emissivity  ... "

# %%
author
# Out:
# Person('{Mansfield}, W.')

# %%
if author.first_names and author.last_names:
    print('True')
# Out:
# True
